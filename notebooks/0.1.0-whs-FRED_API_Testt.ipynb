# %%
from fredapi import Fred
import numpy as np
import requests
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
fred = Fred(api_key='6f2f81fce97aa422c54836a13d08ebe2')
series = ['SP500','GDP']
data = [fred.get_series(x) for x in series]
for i, df in enumerate(data):
    print(df.count())
    df.plot(title=series[i])
    plt.show()
# Out:
# 2517
# 298

# %%
#endpoint = '/repos/:owner/:repo/actions/secrets/public-key'
#requests.get(endpoint) 

fred = Fred(api_key='6f2f81fce97aa422c54836a13d08ebe2')#,response_type='df')
series = ['SP500','FEDFUNDS','FGEXPND']
data = [fred.get_series(x) for x in series]
df = pd.DataFrame()
for i, data_series in enumerate(data):
    #if series[i] = 'FGEXPEND':
    info_list = fred.search(series[i])[['title','units_short']]
    print(info_list)
    #print(data_series.title)
    df[series[i]+' ('+str(info_list['units_short'][0])+')'] = data_series
    #print(df.head())


df_filt = df.fillna(method="ffill")
df_filt.rename(columns={'SP500 (Index)':'SP500 ($  /share)'}, inplace=True)
print(df_filt.dropna(how='any').count())
df_filt.dropna(how='any').head()
df_filt.plot()
# Out:
#              title units_short
# series id
# SP500      S&P 500       Index
#                                   title units_short
# series id
# FEDFUNDS   Effective Federal Funds Rate           %
#                                               title units_short
# series id
# FGEXPND    Federal Government: Current Expenditures   Bil. of $
# SP500 ($  /share)      2325
# FEDFUNDS (%)           2325
# FGEXPND (Bil. of $)    2325
# dtype: int64
# <AxesSubplot:>

# %%
ax = df_filt.plot(secondary_y='FEDFUNDS (%)')
ax2 = ax.twinx()
#ax2.set_yscale('log')

plt.show()

# %%
fred.search('corporate tax rate')#['id','']
# Out:
#                                   id realtime_start realtime_end  \
# series id
# CP                                CP     2021-08-28   2021-08-28
# A053RC1Q027SBEA      A053RC1Q027SBEA     2021-08-28   2021-08-28
# CPATAX                        CPATAX     2021-08-28   2021-08-28
# B075RC1Q027SBEA      B075RC1Q027SBEA     2021-08-28   2021-08-28
# A446RC1Q027SBEA      A446RC1Q027SBEA     2021-08-28   2021-08-28
# ...                              ...            ...          ...
# BOGZ1FA613178003A  BOGZ1FA613178003A     2021-08-28   2021-08-28
# BOGZ1FA613178013Q  BOGZ1FA613178013Q     2021-08-28   2021-08-28
# BOGZ1FA613178013A  BOGZ1FA613178013A     2021-08-28   2021-08-28
# BOGZ1FA615410003Q  BOGZ1FA615410003Q     2021-08-28   2021-08-28
# BOGZ1FA615410003A  BOGZ1FA615410003A     2021-08-28   2021-08-28
#
#                                                                title  \
# series id
# CP                 Corporate Profits After Tax (without IVA and C...
# A053RC1Q027SBEA    National income: Corporate profits before tax ...
# CPATAX             Corporate Profits After Tax with Inventory Val...
# B075RC1Q027SBEA    Federal government current tax receipts: Taxes...
# A446RC1Q027SBEA    Corporate business: Profits before tax (withou...
# ...                                                              ...
# BOGZ1FA613178003A  Finance Companies; Taxes Payable, Other; Liabi...
# BOGZ1FA613178013Q  Finance Companies; Taxes Payable, Tax on Forei...
# BOGZ1FA613178013A  Finance Companies; Taxes Payable, Tax on Forei...
# BOGZ1FA615410003Q  Finance Companies; Capital Transfers Paid, Tax...
# BOGZ1FA615410003A  Finance Companies; Capital Transfers Paid, Tax...
#
#                   observation_start observation_end  frequency  \
# series id
# CP                       1947-01-01      2021-04-01  Quarterly
# A053RC1Q027SBEA          1947-01-01      2021-04-01  Quarterly
# CPATAX                   1947-01-01      2021-04-01  Quarterly
# B075RC1Q027SBEA          1947-01-01      2021-04-01  Quarterly
# A446RC1Q027SBEA          1947-01-01      2021-04-01  Quarterly
# ...                             ...             ...        ...
# BOGZ1FA613178003A        1946-01-01      2020-01-01     Annual
# BOGZ1FA613178013Q        1946-10-01      2021-01-01  Quarterly
# BOGZ1FA613178013A        1946-01-01      2020-01-01     Annual
# BOGZ1FA615410003Q        1946-10-01      2021-01-01  Quarterly
# BOGZ1FA615410003A        1946-01-01      2020-01-01     Annual
#
#                   frequency_short                units units_short  \
# series id
# CP                              Q  Billions of Dollars   Bil. of $
# A053RC1Q027SBEA                 Q  Billions of Dollars   Bil. of $
# CPATAX                          Q  Billions of Dollars   Bil. of $
# B075RC1Q027SBEA                 Q  Billions of Dollars   Bil. of $
# A446RC1Q027SBEA                 Q  Billions of Dollars   Bil. of $
# ...                           ...                  ...         ...
# BOGZ1FA613178003A               A  Millions of Dollars   Mil. of $
# BOGZ1FA613178013Q               Q  Millions of Dollars   Mil. of $
# BOGZ1FA613178013A               A  Millions of Dollars   Mil. of $
# BOGZ1FA615410003Q               Q  Millions of Dollars   Mil. of $
# BOGZ1FA615410003A               A  Millions of Dollars   Mil. of $
#
#                                seasonal_adjustment seasonal_adjustment_short  \
# series id
# CP                 Seasonally Adjusted Annual Rate                      SAAR
# A053RC1Q027SBEA    Seasonally Adjusted Annual Rate                      SAAR
# CPATAX             Seasonally Adjusted Annual Rate                      SAAR
# B075RC1Q027SBEA    Seasonally Adjusted Annual Rate                      SAAR
# A446RC1Q027SBEA    Seasonally Adjusted Annual Rate                      SAAR
# ...                                            ...                       ...
# BOGZ1FA613178003A  Seasonally Adjusted Annual Rate                      SAAR
# BOGZ1FA613178013Q  Seasonally Adjusted Annual Rate                      SAAR
# BOGZ1FA613178013A  Seasonally Adjusted Annual Rate                      SAAR
# BOGZ1FA615410003Q  Seasonally Adjusted Annual Rate                      SAAR
# BOGZ1FA615410003A  Seasonally Adjusted Annual Rate                      SAAR
#
#                                 last_updated popularity  \
# series id
# CP                 2021-08-26 07:51:37-05:00         70
# A053RC1Q027SBEA    2021-08-26 07:51:50-05:00         55
# CPATAX             2021-08-26 07:51:52-05:00         52
# B075RC1Q027SBEA    2021-08-26 07:52:04-05:00         41
# A446RC1Q027SBEA    2021-08-26 07:52:07-05:00         34
# ...                                      ...        ...
# BOGZ1FA613178003A  2021-06-15 06:20:54-05:00          0
# BOGZ1FA613178013Q  2021-06-15 06:20:54-05:00          0
# BOGZ1FA613178013A  2021-03-19 14:15:00-05:00          0
# BOGZ1FA615410003Q  2021-06-10 11:56:26-05:00          0
# BOGZ1FA615410003A  2021-03-11 12:10:28-06:00          0
#
#                                                                notes
# series id
# CP                                        BEA Account Code: A055RC
# A053RC1Q027SBEA    BEA Account Code: A053RC  For more information...
# CPATAX             BEA Account Code: A551RC  A Guide to the Natio...
# B075RC1Q027SBEA    BEA Account Code: B075RC  For more information...
# A446RC1Q027SBEA    BEA Account Code: A446RC  For more information...
# ...                                                              ...
# BOGZ1FA613178003A  Source ID: FA613178003.A  For more information...
# BOGZ1FA613178013Q  Source ID: FA613178013.Q  For more information...
# BOGZ1FA613178013A  Source ID: FA613178013.A  For more information...
# BOGZ1FA615410003Q  Source ID: FA615410003.Q  For more information...
# BOGZ1FA615410003A  Source ID: FA615410003.A  For more information...
#
# [145 rows x 15 columns]

# %%
df = pd.DataFrame({'x': [1,2,0,4], 'y': [1e1, 5e3, 3e2, 3e4]})

ax = df_filt.plot(secondary_y='FEDFUNDS (%)')
ax2 = ax.twinx()
#ax2.set_yscale('log')

plt.show()

# %%
info_list['units_short'][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/w5/yq2jg5rs49z500s594jw0wpc0000gn/T/ipykernel_1423/3457102174.py in <module>
# ----> 1 info_list['units_short'][1]
#
# ~/anaconda3/envs/fin/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     937
#     938         if is_integer(key) and self.index._should_fallback_to_positional():
# --> 939             return self._values[key]
#     940
#     941         elif key_is_scalar:
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
