# %%
from fredapi import Fred
import requests
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-3acc8afce666> in <module>
# ----> 1 from fredapi import Fred
#       2 import requests
#       3 import matplotlib
#       4 import matplotlib.pyplot as plt
#       5 import pandas as pd
#
# ~/anaconda3/envs/fin/lib/python3.8/site-packages/fredapi/__init__.py in <module>
#       1
#       2 from fredapi.version import version as __version__
# ----> 3 from fredapi.fred import Fred
#
# ~/anaconda3/envs/fin/lib/python3.8/site-packages/fredapi/fred.py in <module>
#      12     import urllib2 as url_error
#      13
# ---> 14 import pandas as pd
#      15
#      16 urlopen = url_request.urlopen
#
# ~/anaconda3/envs/fin/lib/python3.8/site-packages/pandas/__init__.py in <module>
#      14
#      15 if missing_dependencies:
# ---> 16     raise ImportError(
# ...

# %%
#https://www.ncei.noaa.gov/support/access-data-service-api-user-documentation
dataTypes = 'WIND_DIR,WIND_SPEED,TEMP'
startDate = '2016-01-01'
endDate = '2016-01-02'
dataset= 'global-marine'# 'land-based-station/noaa-global-temp' #
url_orig = 'https://www.ncei.noaa.gov/access/services/data/v1?dataset=global-marine&dataTypes=WIND_DIR,WIND_SPEED&stations=AUCE&startDate=2016-01-01&endDate=2016-01-02&boundingBox=90,-180,-90,180'
url = 'https://www.ncei.noaa.gov/access/services/data/v1?dataset={}&dataTypes={}&stations=AUCE&startDate={}&endDate={}&boundingBox=90,-180,-90,180&includeAttributes=true&includeStationName=true' \
    .format(dataset, dataTypes, startDate, endDate)
print(url)
print(url_orig)

df = pd.read_csv(url)
df.tail()
# Out:
# https://www.ncei.noaa.gov/access/services/data/v1?dataset=global-marine&dataTypes=WIND_DIR,WIND_SPEED,TEMP&stations=AUCE&startDate=2016-01-01&endDate=2016-01-02&boundingBox=90,-180,-90,180&includeAttributes=true&includeStationName=true
# https://www.ncei.noaa.gov/access/services/data/v1?dataset=global-marine&dataTypes=WIND_DIR,WIND_SPEED&stations=AUCE&startDate=2016-01-01&endDate=2016-01-02&boundingBox=90,-180,-90,180
#   STATION  NAME                 DATE  LATITUDE  LONGITUDE  TEMP  WIND_DIR  \
# 5    AUCE   NaN  2016-01-02T09:09:00     -20.2       57.5   NaN       330
# 6    AUCE   NaN  2016-01-02T12:09:00     -20.2       57.5   NaN       330
# 7    AUCE   NaN  2016-01-02T15:09:00     -20.2       57.5   NaN       330
# 8    AUCE   NaN  2016-01-02T18:09:00     -20.2       57.5   NaN       300
# 9    AUCE   NaN  2016-01-02T21:09:00     -20.2       57.5   NaN       320
#
#    WIND_SPEED
# 5          30
# 6          40
# 7          10
# 8          30
# 9          20

# %%
#https://www.ncei.noaa.gov/support/access-data-service-api-user-documentation
#https://www.ncdc.noaa.gov/cdo-web/datasets/GHCND/locations/FIPS:US/detail
dataTypes = 'PRCP,TAVG,TMAX,TMIN'#'DP01,DP05,DP10,DSND,DSNW,DT00,DT32,DX32,DX70,DX90,SNOW,PRCP'#'WIND_DIR,WIND_SPEED,TEMP'
startDate = '1952-01-01'
endDate = '1970-12-31'
dataset= 'daily-summaries'#'global-summary-of-the-month'#'global-marine'# 'land-based-station/noaa-global-temp' #
stations ='USW00014838'#'USW00014838' #-Marquettte WI #'USW00094728'
url_orig = 'https://www.ncei.noaa.gov/access/services/data/v1?dataset=global-summary-of-the-year&dataTypes={}&stations=ASN00084027&startDate=1952-01-01&endDate=1970-12-31&includeAttributes=true&format=csv'
url = 'https://www.ncei.noaa.gov/access/services/data/v1?dataset={}&dataTypes={}&stations={}&startDate={}&endDate={}&includeAttributes=true&format=csv' \
    .format(dataset, dataTypes, stations, startDate, endDate)
print(url)
print(url_orig)

df = pd.read_csv(url)
df.head()
# Out:
# https://www.ncei.noaa.gov/access/services/data/v1?dataset=daily-summaries&dataTypes=PRCP,TAVG,TMAX,PSUN&stations=USW00014838&startDate=1952-01-01&endDate=1970-12-31&includeAttributes=true&format=csv
# https://www.ncei.noaa.gov/access/services/data/v1?dataset=global-summary-of-the-year&dataTypes={}&stations=ASN00084027&startDate=1952-01-01&endDate=1970-12-31&includeAttributes=true&format=csv
#        STATION        DATE  PRCP PRCP_ATTRIBUTES  PSUN PSUN_ATTRIBUTES  TAVG  \
# 0  USW00014838  1952-01-01     0       T,,0,2400   NaN             NaN   NaN
# 1  USW00014838  1952-01-02     0       T,,0,2400   NaN             NaN   NaN
# 2  USW00014838  1952-01-03     0       T,,0,2400   NaN             NaN   NaN
# 3  USW00014838  1952-01-04     0        ,,0,2400   NaN             NaN   NaN
# 4  USW00014838  1952-01-05     0       T,,0,2400   NaN             NaN   NaN
#
#    TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES
# 0              NaN    17             ,,0
# ...

# %%
#https://www.ncei.noaa.gov/support/access-data-service-api-user-documentation
dataTypes = 'PRCP,TAVG'#'DP01,DP05,DP10,DSND,DSNW,DT00,DT32,DX32,DX70,DX90,SNOW,PRCP'#'WIND_DIR,WIND_SPEED,TEMP'
startDate = '1952-01-01'
endDate = '1970-12-31'
dataset= 'global-summary-of-the-month'#'global-marine'# 'land-based-station/noaa-global-temp' #
stations = 'USW00094728'
url_orig = 'https://www.ncei.noaa.gov/access/services/data/v1?dataset=global-summary-of-the-year&dataTypes={}&stations=ASN00084027&startDate=1952-01-01&endDate=1970-12-31&includeAttributes=true&format=csv'
url = 'https://www.ncei.noaa.gov/access/services/data/v1?dataset={}&dataTypes={}&stations={}&startDate={}&endDate={}&includeAttributes=true&format=csv' \
    .format(dataset, dataTypes, stations, startDate, endDate)
#print(url)
#print(url_orig)

df = pd.read_csv(url)
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00c6d1a38095> in <module>
#      11 #print(url_orig)
#      12
# ---> 13 df = pd.read_csv(url)
#      14 df.tail()
#
# NameError: name 'pd' is not defined

# %%
#datasets https://www.ncdc.noaa.gov/data-access/quick-links
https://www.ncei.noaa.gov/products/land-based-station/noaa-global-temp
    
https://www.ncei.noaa.gov/access/services/data/v1?dataset=daily-summaries
# Out:
#   STATION                 DATE  LATITUDE  LONGITUDE  WIND_DIR  WIND_SPEED
# 5    AUCE  2016-01-02T09:09:00     -20.2       57.5       330          30
# 6    AUCE  2016-01-02T12:09:00     -20.2       57.5       330          40
# 7    AUCE  2016-01-02T15:09:00     -20.2       57.5       330          10
# 8    AUCE  2016-01-02T18:09:00     -20.2       57.5       300          30
# 9    AUCE  2016-01-02T21:09:00     -20.2       57.5       320          20
